# %%
# pip install pandas 
# DataFrame()
#Data Series()

import numpy as np
import pandas as pd

arr = np.array([20,30,40,50])
arr2 = np.array([[20,20,30],[10,2,4]])
lst = [10, 'mgmg', '3', 60, 30.5]

dt = {
    'name':['mg mg', 'aung aung', 'kyaw kyaw', 'aye aye'],
    'age': [10,20,30,40],
    'address': ['mdy', 'ygn', 'bgo', 'sg']
}


df = pd.DataFrame(dt)

print(df[['name','address', 'age']])

# %%
import pandas as pd
# df = pd.DataFrame()
# openpyxl
file_path= "C:\\Users\\E15\\PycharmProjects\\AI_Level1_Class1\\PandasTutorial\\dataset\\myfle.xlsx"
df = pd.read_excel(r"dataset\myfle.xlsx")

df.drop_duplicates()

# %%
import pandas as pd

data1 = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance'],
    'Employee': ['A', 'B', 'C', 'D', 'E', 'F'],
    'Salary': [6000, 7000, 4000, 4500, 8000, 7500],
    'Bonus': [500, 600, 200, 250, 800, 750]
}

data2 = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance'],
    'Employee': ['G', 'H', 'I', 'J', 'K', 'L'],
    'Salary': [6000, 7000, 4000, 4500, 8000, 7500],
    'Bonus': [500, 600, 200, 250, 800, 750]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

result = pd.merge(df1, df2, how='inner', on='Department')

df1['Department'] = df1['Department']+df2['Department']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance'],
    'Employee': ['A', 'B', 'C', 'D', 'E', 'F'],
    'Salary': [6000, 7000, 4000, 4500, 8000, 7500],
    'Bonus': [500, 600, 200, 250, 800, 750]
}
df = pd.DataFrame(data)
sns.scatterplot(data=df, x='Employee', y='Bonus')
plt.show()
