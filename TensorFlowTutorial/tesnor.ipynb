# %%
import tensorflow as tf

tf.__version__

# %%
tensor = tf.constant([[1,2,3],[2,3,4]])
tensor

# %%
scalar = tf.constant(4)
vector = tf.constant([1,2,3,4])
matrix = tf.constant([[1,2,3,4],[3,4,5,6]])
ten3d= tf.constant([[[1,2],[3,4],[6,7]]])

# %%
vector = tf.constant([1,2,3,4])
a = tf.slice(vector, begin=[1], size=[3])
b = vector[1:3+1]
print(a)
print(b)

# %%
matrix = tf.constant([
    [1,2,3,4],
    [3,4,5,6],
    [7,8,9,10]
    ])

a = tf.slice(matrix, begin=[1,1], size=[1,3])
print(a)

# %%
ten = tf.constant([0,0,0,0,0,0,0])

ten=tf.scatter_nd(indices=[[2],[4],[5]], updates=[5,4,10], shape=[7])

print(ten)

# %%
matrix = tf.constant([
    [1,2,3,4],
    [3,4,5,6],
    [7,8,9,10]
    ])

mat = tf.reshape(matrix, [4,3])
mat

# %%
str_ten1 = tf.constant('hello wrold')
str_ten2 = tf.constant(['hello','wrold'])
str_ten3 = tf.constant([['hello','wrold'],['please', 'apple']])

# %%
str_ten1 = tf.constant('hello wrold')
str_ten2 = tf.constant('Hello Wrold')

# result = tf.strings.join([str_ten1, str_ten2], separator=", ")
# result = tf.strings.split(str_ten2)
# result = tf.strings.unicode_split(str_ten2, 'UTF-8')
# result = tf.equal(str_ten1, str_ten2)
# result = tf.strings.lower(str_ten2)

# %%
con1 =tf.constant([2,3,4])
con2 =tf.constant([2,3,4])

sum = tf.add(con1, con2)
sum
